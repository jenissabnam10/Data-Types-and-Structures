# %% [markdown]
# **Data Types and Structures: Practical Assignment Questions**
#
# 1. Write a code to create a string with your name and print it.

# %%
# prompt: Write a code to create a string with your name and print it.

# Create a string with your name
my_name = "Jenis Sabnam"  # Replace "Your Name" with your actual name

# Print the string
my_name
# Out:
# 'Jenis Sabnam'

# %% [markdown]
# 2. Write a code to find the length of the string "Hello World".

# %%
# prompt: Write a code to find the length of the string "Hello World".

# Find the length of the string "Hello World"
string = ("Hello World")
length_of_string = len(string)

# Print the length of the string
length_of_string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-59d8ceb828a6> in <cell line: 5>()
#       3 # Find the length of the string "Hello World"
#       4 string = ("Hello World")
# ----> 5 length_of_string = len(string)
#       6
#       7 # Print the length of the string
#
# TypeError: 'int' object is not callable

# %% [markdown]
# 3. Write a code to slice the first 3 characters from the string "Python Programming".

# %%
# prompt: Write a code to slice the first 3 characters from the string "Python Programming".

string = "Python Programming"
print(string[:3])
# Out:
# Pyt

# %% [markdown]
# 4. Write a code to convert the string "hello" to uppercase.

# %%
text = 'hello world'
uppercase_text = text.upper()
print(uppercase_text)

# Output:
# 'HELLO WORLD'
# Out:
# HELLO WORLD

# %% [markdown]
# 5. Write a code to replace the word "apple" with "orange" in the string "I like apple".

# %%
a = ["I like apple",]
a = [s.replace('apple','orange') for s in a]
b = (a)
print(b)
# > ['I like orange',]
# Out:
# ['I like orange']

# %% [markdown]
# 6. Write a code to create a list with numbers 1 to 5 and print it.

# %%
numbers = list(range(1, 5))
print(numbers)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# 7. Write a code to append the number 10 to the list [1, 2, 3, 4].

# %%
# prompt: Write a code to append the number 10 to the list [1, 2, 3, 4].

# 7. Write a code to append the number 10 to the list [1, 2, 3, 4].
numbers = [1, 2, 3, 4]
numbers.append(10)
numbers
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# 8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].

# %%
# prompt: Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].

numbers = [1, 2, 3, 4, 5]
numbers.remove(3)
numbers
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# 9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'].

# %%
# prompt: Write a code to access the second element in the list ['a', 'b', 'c', 'd']

my_list = ['a', 'b', 'c', 'd']
second_element = my_list[1]
second_element
# Out:
# 'b'

# %% [markdown]
# 10. Write a code to reverse the list [10, 20, 30, 40, 50].

# %%
# prompt: Write a code to reverse the list [10, 20, 30, 40, 50].

numbers = [10, 20, 30, 40, 50]
numbers.reverse()
numbers
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# 11. Write a code to create a tuple with the elements 10, 20, 30 and print it.

# %%
# prompt: Write a code to create a tuple with the elements 10, 20, 30 and print it.

my_tuple = (10, 20, 30)
my_tuple
# Out:
# (10, 20, 30)

# %% [markdown]
# 12. Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').

# %%
# prompt: Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').

my_tuple = ('apple', 'banana', 'cherry')
first_element = my_tuple[0]
first_element
# Out:
# 'apple'

# %% [markdown]
# 13. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).

# %%
# prompt: Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).

my_tuple = (1, 2, 3, 2, 4, 2)
count_of_twos = my_tuple.count(2)
count_of_twos
# Out:
# 3

# %% [markdown]
# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

# %%
# prompt: Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

my_tuple = ('dog', 'cat', 'rabbit')
index_of_cat = my_tuple.index('cat')
index_of_cat
# Out:
# 1

# %% [markdown]
# 15. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').

# %%
# prompt: Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').

my_tuple = ('apple', 'orange', 'banana')
if "banana" in my_tuple:
  print("banana is present in the tuple")
else:
  print ("banana is not present in the tuple")
# Out:
# banana is present in the tuple

# %% [markdown]
# 16. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.

# %%
# prompt: Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.

my_set = {1, 2, 3, 4, 5}
my_set
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 17. Write a code to add the element 6 to the set {1, 2, 3, 4}.

# %%
# prompt: Write a code to add the element 6 to the set {1, 2, 3, 4}.

my_set = {1, 2, 3, 4}
my_set.add(6)
my_set
# Out:
# {1, 2, 3, 4, 6}

# %% [markdown]
# 18. Write a code to create a tuple with the elements 10, 20, 30 and print it.

# %%
# prompt: Write a code to create a tuple with the elements 10, 20, 30 and print it.

my_tuple = (10, 20, 30)
my_tuple
# Out:
# (10, 20, 30)

# %% [markdown]
# 19.  Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').

# %%
# prompt:  Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').

my_tuple = ('apple', 'banana', 'cherry')
first_element = my_tuple[0]
first_element
# Out:
# 'apple'

# %% [markdown]
# 20.  Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).

# %%
# prompt:  Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).

my_tuple = (1, 2, 3, 2, 4, 2)
count_of_twos = my_tuple.count(2)
count_of_twos
# Out:
# 3

# %% [markdown]
# 21. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

# %%
# prompt: Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

my_tuple = ('dog', 'cat', 'rabbit')
index_of_cat = my_tuple.index('cat')
index_of_cat
# Out:
# 1

# %% [markdown]
# 22. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').

# %%
# prompt: Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').

my_tuple = ('apple', 'orange', 'banana')
if "banana" in my_tuple:
  print("banana is present in the tuple")
else:
  print ("banana is not present in the tuple")
# Out:
# banana is present in the tuple

# %% [markdown]
# 23. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.

# %%
# prompt: Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.

my_set = {1, 2, 3, 4, 5}
my_set
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 24.Write a code to add the element 6 to the set {1, 2, 3, 4}.

# %%
# prompt: Write a code to add the element 6 to the set {1, 2, 3, 4}.

my_set = {1, 2, 3, 4}
my_set.add(6)
my_set
# Out:
# {1, 2, 3, 4, 6}
